# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import random
from tensorflow.compiler.tf2xla.python import xla

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

print("4 Random Training samples and labels")
idx1, idx2, idx3, idx4 = random.sample(range(0, x_train.shape[0]), 4)

img1 = (x_train[idx1], y_train[idx1])
img2 = (x_train[idx2], y_train[idx2])
img3 = (x_train[idx3], y_train[idx3])
img4 = (x_train[idx4], y_train[idx4])

imgs = [img1, img2, img3, img4]

plt.figure(figsize=(10, 10))

for idx, item in enumerate(imgs):
    image, label = item[0], item[1]
    plt.subplot(2, 2, idx + 1)
    plt.imshow(image, cmap="gray")
    plt.title(f"Label : {label}")
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# 4 Random Training samples and labels

# %%
class FFDense(keras.layers.Layer):
    """
    A custom ForwardForward-enabled Dense layer. It has an implementation of the
    Forward-Forward network internally for use.
    This layer must be used in conjunction with the `FFNetwork` model.
    """

    def __init__(
        self,
        units,
        optimizer,
        loss_metric,
        num_epochs=50,
        use_bias=True,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.dense = keras.layers.Dense(
            units=units,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
        )
        self.relu = keras.layers.ReLU()
        self.optimizer = optimizer
        self.loss_metric = loss_metric
        self.threshold = 1.5
        self.num_epochs = num_epochs

    def call(self, x):
        x_norm = tf.norm(x, ord=2, axis=1, keepdims=True)
        x_norm = x_norm + 1e-4
        x_dir = x / x_norm
        res = self.dense(x_dir)
        return self.relu(res)

    def forward_forward(self, x_pos, x_neg):
        for i in range(self.num_epochs):
            with tf.GradientTape() as tape:
                g_pos = tf.math.reduce_mean(tf.math.pow(self.call(x_pos), 2), 1)
                g_neg = tf.math.reduce_mean(tf.math.pow(self.call(x_neg), 2), 1)

                loss = tf.math.log(
                    1
                    + tf.math.exp(
                        tf.concat([-g_pos + self.threshold, g_neg - self.threshold], 0)
                    )
                )
                mean_loss = tf.cast(tf.math.reduce_mean(loss), tf.float32)
                self.loss_metric.update_state([mean_loss])
            gradients = tape.gradient(mean_loss, self.dense.trainable_weights)
            self.optimizer.apply_gradients(zip(gradients, self.dense.trainable_weights))
        return (
            tf.stop_gradient(self.call(x_pos)),
            tf.stop_gradient(self.call(x_neg)),
            self.loss_metric.result(),
        )

# %%
class FFNetwork(keras.Model):

    def __init__(
        self,
        dims,
        layer_optimizer=keras.optimizers.legacy.Adam(learning_rate=0.05),
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.layer_optimizer = layer_optimizer
        self.loss_var = tf.Variable(0.0, trainable=False, dtype=tf.float32)
        self.loss_count = tf.Variable(0.0, trainable=False, dtype=tf.float32)
        self.layer_list = [keras.Input(shape=(dims[0],))]
        for d in range(len(dims) - 1):
            self.layer_list += [
                FFDense(
                    dims[d + 1],
                    optimizer=self.layer_optimizer,
                    loss_metric=keras.metrics.Mean(),
                )
            ]

    @tf.function(reduce_retracing=True)
    def overlay_y_on_x(self, data):
        X_sample, y_sample = data
        max_sample = tf.reduce_max(X_sample, axis=0, keepdims=True)
        max_sample = tf.cast(max_sample, dtype=tf.float64)
        X_zeros = tf.zeros([10], dtype=tf.float64)
        X_update = xla.dynamic_update_slice(X_zeros, max_sample, [y_sample])
        X_sample = xla.dynamic_update_slice(X_sample, X_update, [0])
        return X_sample, y_sample

    @tf.function(reduce_retracing=True)
    def predict_one_sample(self, x):
        goodness_per_label = []
        x = tf.reshape(x, [tf.shape(x)[0] * tf.shape(x)[1]])
        for label in range(10):
            h, label = self.overlay_y_on_x(data=(x, label))
            h = tf.reshape(h, [-1, tf.shape(h)[0]])
            goodness = []
            for layer_idx in range(1, len(self.layer_list)):
                layer = self.layer_list[layer_idx]
                h = layer(h)
                goodness += [tf.math.reduce_mean(tf.math.pow(h, 2), 1)]
            goodness_per_label += [
                tf.expand_dims(tf.reduce_sum(goodness, keepdims=True), 1)
            ]
        goodness_per_label = tf.concat(goodness_per_label, 1)
        return tf.cast(tf.argmax(goodness_per_label, 1), tf.float64)

    def predict(self, data):
        x = data
        preds = list()
        preds = tf.map_fn(fn=self.predict_one_sample, elems=x)
        return np.asarray(preds, dtype=int)


    @tf.function(jit_compile=True)
    def train_step(self, data):
        x, y = data

        # Flatten op
        x = tf.reshape(x, [-1, tf.shape(x)[1] * tf.shape(x)[2]])

        x_pos, y = tf.map_fn(fn=self.overlay_y_on_x, elems=(x, y))

        random_y = tf.random.shuffle(y)
        x_neg, y = tf.map_fn(fn=self.overlay_y_on_x, elems=(x, random_y))

        h_pos, h_neg = x_pos, x_neg

        for idx, layer in enumerate(self.layers):
            if isinstance(layer, FFDense):
                print(f"Training layer {idx+1} now : ")
                h_pos, h_neg, loss = layer.forward_forward(h_pos, h_neg)
                self.loss_var.assign_add(loss)
                self.loss_count.assign_add(1.0)
            else:
                print(f"Passing layer {idx+1} now : ")
                x = layer(x)
        mean_res = tf.math.divide(self.loss_var, self.loss_count)
        return {"FinalLoss": mean_res}

# %%
x_train = x_train.astype(float) / 255
x_test = x_test.astype(float) / 255
y_train = y_train.astype(int)
y_test = y_test.astype(int)

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

train_dataset = train_dataset.batch(60000)
test_dataset = test_dataset.batch(10000)

# %%
model = FFNetwork(dims=[784, 500, 500])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.05),
    loss="mse",
    jit_compile=True,
    metrics=[keras.metrics.Mean()],
)

epochs = 250
history = model.fit(train_dataset, epochs=epochs)
# Out:
# Epoch 1/250
# Training layer 1 now :
# Training layer 2 now :
# Training layer 1 now :
# Training layer 2 now :
# 1/1 [==============================] - 65s 65s/step - FinalLoss: 0.7276
# Epoch 2/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.6994
# Epoch 3/250
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.6754
# Epoch 4/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.6447
# Epoch 5/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.6180
# Epoch 6/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5958
# Epoch 7/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5767
# Epoch 8/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5604
# Epoch 9/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5463
# Epoch 10/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5339
# Epoch 11/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5229
# Epoch 12/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5131
# Epoch 13/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5041
# Epoch 14/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4959
# Epoch 15/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4884
# Epoch 16/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4815
# Epoch 17/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4751
# Epoch 18/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4692
# Epoch 19/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4636
# Epoch 20/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4585
# Epoch 21/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4537
# Epoch 22/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4493
# Epoch 23/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4451
# Epoch 24/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4413
# Epoch 25/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4376
# Epoch 26/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4341
# Epoch 27/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4308
# Epoch 28/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4277
# Epoch 29/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4247
# Epoch 30/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4218
# Epoch 31/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4191
# Epoch 32/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4165
# Epoch 33/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4141
# Epoch 34/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4117
# Epoch 35/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4095
# Epoch 36/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4074
# Epoch 37/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4053
# Epoch 38/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4033
# Epoch 39/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4014
# Epoch 40/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3995
# Epoch 41/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3977
# Epoch 42/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3960
# Epoch 43/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3943
# Epoch 44/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3926
# Epoch 45/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3910
# Epoch 46/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3895
# Epoch 47/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3880
# Epoch 48/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3866
# Epoch 49/250
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3852
# Epoch 50/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3838
# Epoch 51/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3825
# Epoch 52/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3811
# Epoch 53/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3799
# Epoch 54/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3786
# Epoch 55/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3774
# Epoch 56/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3762
# Epoch 57/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3750
# Epoch 58/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3739
# Epoch 59/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.
250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3119
# Epoch 196/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3117
# Epoch 197/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3115
# Epoch 198/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3113
# Epoch 199/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3111
# Epoch 200/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3109
# Epoch 201/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3108
# Epoch 202/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3106
# Epoch 203/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3104
# Epoch 204/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3102
# Epoch 205/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3101
# Epoch 206/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3099
# Epoch 207/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3097
# Epoch 208/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3095
# Epoch 209/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3094
# Epoch 210/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3092
# Epoch 211/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3090
# Epoch 212/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3089
# Epoch 213/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3087
# Epoch 214/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3085
# Epoch 215/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3084
# Epoch 216/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3082
# Epoch 217/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3081
# Epoch 218/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3079
# Epoch 219/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3078
# Epoch 220/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3076
# Epoch 221/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3074
# Epoch 222/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3073
# Epoch 223/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3071
# Epoch 224/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3070
# Epoch 225/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3069
# Epoch 226/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3067
# Epoch 227/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3066
# Epoch 228/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3064
# Epoch 229/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3063
# Epoch 230/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3061
# Epoch 231/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3060
# Epoch 232/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3058
# Epoch 233/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3057
# Epoch 234/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3056
# Epoch 235/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3054
# Epoch 236/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3053
# Epoch 237/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3052
# Epoch 238/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3050
# Epoch 239/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3049
# Epoch 240/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3048
# Epoch 241/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3046
# Epoch 242/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3045
# Epoch 243/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3044
# Epoch 244/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3042
# Epoch 245/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3041
# Epoch 246/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3040
# Epoch 247/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3039
# Epoch 248/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3037
# Epoch 249/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3036
# Epoch 250/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3035

# %%
preds = model.predict(tf.convert_to_tensor(x_test))

preds = preds.reshape((preds.shape[0], preds.shape[1]))

results = accuracy_score(preds, y_test)

print(f"Test Accuracy score : {results*100}%")

plt.plot(range(len(history.history["FinalLoss"])), history.history["FinalLoss"])
plt.title("Loss over training")
plt.show()
# Out:
# Test Accuracy score : 97.68%

# %%
X = []
Y = []

# %%
#for learning rate 0.03
#Test accuracy score: 97.68%
#Final Loss: 0.3121
X.append(range(len(history.history["FinalLoss"])))
Y.append(history.history["FinalLoss"])

# %%
#for learning rate 0.01
#Test Accuracy Score: 97.32%
#Final Loss: 0.3413

preds = model.predict(tf.convert_to_tensor(x_test))

preds = preds.reshape((preds.shape[0], preds.shape[1]))

results = accuracy_score(preds, y_test)

print(f"Test Accuracy score : {results*100}%")

plt.plot(range(len(history.history["FinalLoss"])), history.history["FinalLoss"])
plt.title("Loss over training")
plt.show()
# Out:
# Test Accuracy score : 97.32%

# %%
#for learning rate 0.01
X.append(range(len(history.history["FinalLoss"])))
Y.append(history.history["FinalLoss"])

# %%
len(X)
# Out:
# 2

# %%
plt.plot(X[0], Y[0])
plt.plot(X[1], Y[1])
plt.show()

# %%
#for learning rate 0.05
#Test Accuracy Score: 97.58%
#Final Loss: 0.3035

preds = model.predict(tf.convert_to_tensor(x_test))

preds = preds.reshape((preds.shape[0], preds.shape[1]))

results = accuracy_score(preds, y_test)

print(f"Test Accuracy score : {results*100}%")

plt.plot(range(len(history.history["FinalLoss"])), history.history["FinalLoss"])
plt.title("Loss over training")
plt.show()
# Out:
# Test Accuracy score : 97.58%

# %%
#for learning rate 0.05
X.append(range(len(history.history["FinalLoss"])))
Y.append(history.history["FinalLoss"])

# %%
plt.plot(X[0], Y[0], label = "LR : 0.03")
plt.plot(X[1], Y[1], label = "LR: 0.01")
plt.plot(X[2], Y[2], label = "LR: 0.05")
plt.title("Influence of Learning Rate on Loss")
plt.legend()
plt.show()
